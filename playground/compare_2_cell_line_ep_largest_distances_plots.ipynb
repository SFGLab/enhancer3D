# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

gm12878_hffc6_denisovan_genes_with_biggest_distance_difference_df = pd.read_csv('./gm12878_hffc6_denisovan_genes_with_biggest_distance_difference_df.csv')
gm12878_hffc6_denisovan_genes_with_biggest_distance_difference_df
# Out:
#                  gene_id  dist_diff_avg_gm12878  dist_diff_avg_hffc6  \
# 0      ENSG00000286693.1              52.464194             9.911344
# 1      ENSG00000232024.2              49.741612             9.673261
# 2      ENSG00000288002.1              51.625182            12.232169
# 3      ENSG00000223727.6              45.367012             7.953170
# 4      ENSG00000113805.9              45.278395             9.584774
# ...                  ...                    ...                  ...
# 17825  ENSG00000254539.1               6.681310             6.679518
# 17826  ENSG00000285867.1               6.042209             6.040425
# 17827  ENSG00000232173.2               6.332904             6.332052
# 17828  ENSG00000248442.2              23.164853            23.164738
# 17829  ENSG00000131737.7              13.433528            13.433553
#
#        dist_diff_avg
# 0          42.552850
# 1          40.068351
# 2          39.393014
# 3          37.413842
# 4          35.693621
# ...              ...
# 17825       0.001792
# 17826       0.001784
# 17827       0.000852
# 17828       0.000115
# 17829       0.000025
#
# [17830 rows x 4 columns]

# %%
plt.figure(figsize=(15, 10))
sns.scatterplot(x='gene_id', y='dist_diff_avg', data=gm12878_hffc6_denisovan_genes_with_biggest_distance_difference_df)
plt.xticks(
    rotation=90,
    fontsize=2,
)

plt.xlabel('Gene ID')
plt.ylabel('Distance Difference')

plt.title('Biggest Distance Difference between GM12878 and HFFC6 Neanderthal')

plt.tight_layout()
plt.show()
