# %%
# %load_ext autoreload
# %autoreload 2

# %%
from chromatin_model import *

# %%
import os
import logging

logging.basicConfig(level=logging.INFO)
model = load_3dgnome_model_ensemble_from_filesystem(
    os.path.abspath('../data/models/models3D_GM12878_Deni/results_GM12878_Deni_chr1_74280_3521135/'),
    'chr1_74280_3521135'
)
# Out:
# INFO:chromatin_model.loaders:Loading 100 models for chr1_74280_3521135
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 92
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 78
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 87
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 65
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 70
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 95
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 14
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 80
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 77
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 62
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 13
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 88
# INFO:chromatin_model.loaders:Loading model chr1_74280_3521135 63
# ...

# %%
model.coordinates_stack.shape
# Out:
# (100, 2622, 3)

# %%
pack_chromatin_model_ensemble_to_filesystem(os.path.abspath('../data/models/packed'), model)

# %%
model = unpack_chromatin_model_ensemble_from_filesystem(os.path.abspath('../data/models/packed'), model_name='chr1_74280_3521135')
